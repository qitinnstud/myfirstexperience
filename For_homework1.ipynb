# %% [markdown]
# <a href="https://colab.research.google.com/github/qitinnstud/myfirstexperience/blob/For_homework/For_homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Импорт библиотеки pandas

# %%
import pandas as pd
#from google.colab import files
#uploaded = files.upload()
#import io
#df = pd.read_csv(io.BytesIO(uploaded['Weather Data.csv']))

# %% [markdown]
# Монтирую google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Читаю DataFrame в переменную df и вывожу первые 11 строк

# %%
df0=pd.read_csv("drive/MyDrive/Weather_Data.csv");
df0.head(11)
# Out:
#          Date/Time  Temp_C Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8             -3.9       86.0              4.0
# 1    1/1/2012 1:00    -1.8             -3.7       87.0              4.0
# 2    1/1/2012 2:00    -1.8             -3.4       89.0              7.0
# 3    1/1/2012 3:00    -1.5             -3.2       88.0              6.0
# 4    1/1/2012 4:00    -1.5             -3.3       88.0              7.0
# 5    1/1/2012 5:00    -1.4             -3.3       87.0              9.0
# 6    1/1/2012 6:00    -1.5             -3.1       89.0              7.0
# 7    1/1/2012 7:00    -1.4             -3.6       85.0              7.0
# 8    1/1/2012 8:00    -1.4             -3.6       85.0              9.0
# 9    1/1/2012 9:00    -1.3             -3.1       88.0             15.0
# 10  1/1/2012 10:00    -1.0             -2.3       91.0              9.0
#
#     Visibility_km  Press_kPa               Weather
# 0             8.0     101.24                   Fog
# 1             8.0     101.24                   Fog
# 2             4.0     101.26  Freezing Drizzle,Fog
# 3             4.0     101.27  Freezing Drizzle,Fog
# 4             4.8     101.23                   Fog
# 5             6.4     101.27                   Fog
# 6             6.4     101.29                   Fog
# 7             8.0     101.26                   Fog
# 8             8.0     101.23                   Fog
# 9             4.0     101.20                   Fog
# 10            1.2     101.15                   Fog

# %%
#df.to_csv("drive/MyDrive/Weather_Data1.csv",sep='#',index=False)

# %%
url='https://raw.githubusercontent.com/qitinnstud/myfirstexperience/For_homework/Weather_Data.raw'
df = pd.read_csv(url, sep=',')
df.head()
# Out:
#        Date/Time  Temp_C Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8             -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8             -3.7       87.0              4.0
# 2  1/1/2012 2:00    -1.8             -3.4       89.0              7.0
# 3  1/1/2012 3:00    -1.5             -3.2       88.0              6.0
# 4  1/1/2012 4:00    -1.5             -3.3       88.0              7.0
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Запрос инфо датафрейма. Вывод информации о колонках (заголовках) и типа данных в них:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8409 non-null   float64
#  2   Dew Point Temp_C  8407 non-null   object
#  3   Rel Hum_%         8412 non-null   float64
#  4   Wind Speed_km/h   8412 non-null   float64
#  5   Visibility_km     8410 non-null   float64
#  6   Press_kPa         8409 non-null   float64
#  7   Weather           8408 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 549.1+ KB

# %% [markdown]
# Запрос статистики датафрейма (число строк, среднее, СТО, мин, макс. и квартили):

# %%
df.describe()
# Out:
#             Temp_C    Rel Hum_%  Wind Speed_km/h  Visibility_km    Press_kPa
# count  8409.000000  8412.000000      8412.000000    8410.000000  8409.000000
# mean      8.986027    66.387542        14.865668      28.594815   101.078329
# std      11.777265    16.498184         8.643924      12.079834     0.837151
# min     -23.300000    18.000000         0.000000       0.200000    97.520000
# 25%       0.100000    55.000000         9.000000      24.100000   100.590000
# 50%       9.800000    67.000000        13.000000      25.000000   101.100000
# 75%      19.100000    80.000000        20.000000      25.000000   101.610000
# max      33.000000   100.000000        83.000000     100.690000   103.650000

# %% [markdown]
# включая стр. тип object:

# %%
df.describe(include='object')
# Out:
#             Date/Time Dew Point Temp_C       Weather
# count            8784             8407          8408
# unique           8784              490            17
# top     1/1/2012 0:00             12.9  Mainly Clear
# freq                1               47          2105

# %% [markdown]
# Дата-время представлиены типом 'object'. "Преимущественно ясно" встречается чаще - 2106 вхождений.

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64
