# %% [markdown]
# <a href="https://colab.research.google.com/github/qitinnstud/myfirstexperience/blob/For_homework/For_homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Импорт библиотеки pandas

# %%
import pandas as pd

# %% [markdown]
# Читаю DataFrame c GitHub в переменную df и вывожу несколько строк

# %%
#df.to_csv("drive/MyDrive/Weather_Data1.csv",sep='|',index=False)

url='https://raw.githubusercontent.com/qitinnstud/myfirstexperience/For_homework/Weather_Data.raw'
df = pd.read_csv(url, sep=',')
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 2  1/1/2012 2:00    -1.8              -3.4       89.0              7.0
# 3  1/1/2012 3:00    -1.5              -3.2       88.0              6.0
# 4  1/1/2012 4:00    -1.5              -3.3       88.0              7.0
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Замена типа 'object' на 'datestamp'

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %% [markdown]
# Подсчет пустых значений

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              5
# Dew Point Temp_C    8
# Rel Hum_%           2
# Wind Speed_km/h     2
# Visibility_km       4
# Press_kPa           5
# Weather             6
# dtype: int64

# %% [markdown]
# Всего пропусков:

# %%
df.isna().sum().sum()
# Out:
# 32

# %% [markdown]
# Сохраняем 'маску-пропуски' в DF x :

# %%
x=df.isnull()
x.head()
# Out:
#    Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      False   False             False      False            False
# 1      False   False             False      False            False
# 2      False   False             False      False            False
# 3      False   False             False      False            False
# 4      False   False             False      False            False
#
#    Visibility_km  Press_kPa  Weather
# 0          False      False    False
# 1          False      False    False
# 2          False      False    False
# 3          False      False    False
# 4          False      False    False

# %% [markdown]
# Выводим строки в котором есть хоть один NaN :

# %%
#df.loc[df.isnull()[:] == True] - не получилось...((
x['or']=x.astype('Int64').sum(axis=1).astype('bool') #Ну да, вопрос: как 'по-нормальному' векторизовать функцию OR в python?
df[x['or']!=False]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 48   2012-01-03 00:00:00    -9.0             -16.0       57.0
# 81   2012-01-04 09:00:00   -16.8               NaN       61.0
# 381  2012-01-16 21:00:00     NaN             -17.1       71.0
# 812  2012-02-03 20:00:00    -4.2               NaN       77.0
# 1447 2012-03-01 07:00:00    -4.9               NaN       83.0
# 1771 2012-03-14 19:00:00     0.3               NaN        NaN
# 2284 2012-04-05 04:00:00     NaN              -5.2       61.0
# 3246 2012-05-15 06:00:00    16.3               NaN       80.0
# 4116 2012-06-20 12:00:00    29.1               NaN       58.0
# 4497 2012-07-06 09:00:00     NaN              16.0       19.0
# 5623 2012-08-22 07:00:00    18.9              12.1       65.0
# 6455 2012-09-25 23:00:00     NaN               9.2       73.0
# 6877 2012-10-13 13:00:00     NaN              -2.8       45.0
# 7487 2012-11-07 23:00:00    -0.7              -4.7        NaN
# 8227 2012-12-08 19:00:00     0.9               0.2       95.0
# 8628 2012-12-25 12:00:00    -9.4               NaN       67.0
# 8773 2012-12-31 13:00:00    -4.6               NaN       86.0
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 48               28.0            NaN     100.35   Snow Showers
# 81                9.0            NaN     101.68  Mostly Cloudy
# 381              11.0          25.00        NaN         Cloudy
# 812              11.0          25.00     102.16  Mostly Cloudy
# 1447             30.0            NaN     100.59           Snow
# 1771             15.0           8.00     102.07            NaN
# 2284             17.0          25.00     100.47  Mostly Cloudy
# 3246              9.0          24.10        NaN            NaN
# 4116             20.0          24.10     101.00   Mainly Clear
# 4497              NaN         100.69        NaN            NaN
# 5623             15.0          48.30        NaN            NaN
# 6455             17.0          25.00     101.03         Cloudy
# 6877              NaN          48.30        NaN   Mainly Clear
# 7487             22.0          25.00     101.55  Mostly Cloudy
# 8227              9.0           6.40     100.61            NaN
# 8628              9.0          24.10     101.92         Cloudy
# 8773              4.0            NaN     100.63            NaN

# %% [markdown]
# То же:

# %%
# Нашел фукцию any ("Oh, how this all is not easy!"):
y['or']=x.any(axis=1)
df[y['or']==True]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 48   2012-01-03 00:00:00    -9.0             -16.0       57.0
# 81   2012-01-04 09:00:00   -16.8               NaN       61.0
# 381  2012-01-16 21:00:00     NaN             -17.1       71.0
# 812  2012-02-03 20:00:00    -4.2               NaN       77.0
# 1447 2012-03-01 07:00:00    -4.9               NaN       83.0
# 1771 2012-03-14 19:00:00     0.3               NaN        NaN
# 2284 2012-04-05 04:00:00     NaN              -5.2       61.0
# 3246 2012-05-15 06:00:00    16.3               NaN       80.0
# 4116 2012-06-20 12:00:00    29.1               NaN       58.0
# 4497 2012-07-06 09:00:00     NaN              16.0       19.0
# 5623 2012-08-22 07:00:00    18.9              12.1       65.0
# 6455 2012-09-25 23:00:00     NaN               9.2       73.0
# 6877 2012-10-13 13:00:00     NaN              -2.8       45.0
# 7487 2012-11-07 23:00:00    -0.7              -4.7        NaN
# 8227 2012-12-08 19:00:00     0.9               0.2       95.0
# 8628 2012-12-25 12:00:00    -9.4               NaN       67.0
# 8773 2012-12-31 13:00:00    -4.6               NaN       86.0
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 48               28.0            NaN     100.35   Snow Showers
# 81                9.0            NaN     101.68  Mostly Cloudy
# 381              11.0          25.00        NaN         Cloudy
# 812              11.0          25.00     102.16  Mostly Cloudy
# 1447             30.0            NaN     100.59           Snow
# 1771             15.0           8.00     102.07            NaN
# 2284             17.0          25.00     100.47  Mostly Cloudy
# 3246              9.0          24.10        NaN            NaN
# 4116             20.0          24.10     101.00   Mainly Clear
# 4497              NaN         100.69        NaN            NaN
# 5623             15.0          48.30        NaN            NaN
# 6455             17.0          25.00     101.03         Cloudy
# 6877              NaN          48.30        NaN   Mainly Clear
# 7487             22.0          25.00     101.55  Mostly Cloudy
# 8227              9.0           6.40     100.61            NaN
# 8628              9.0          24.10     101.92         Cloudy
# 8773              4.0            NaN     100.63            NaN

# %% [markdown]
# Выводим корреляционную "матрицу":

# %%
cr=df.corr()
cr.style.background_gradient(cmap='coolwarm')
# Out:
# <ipython-input-95-b3fc5f1be178>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cr=df.corr()
# <style type="text/css">
# #T_71279_row0_col0, #T_71279_row1_col1, #T_71279_row2_col2, #T_71279_row3_col3, #T_71279_row4_col4, #T_71279_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T
row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_71279_row3_col4" class="data row3 col4" >0.004947</td>
#       <td id="T_71279_row3_col5" class="data row3 col5" >-0.356738</td>
#     </tr>
#     <tr>
#       <th id="T_71279_level0_row4" class="row_heading level0 row4" >Visibility_km</th>
#       <td id="T_71279_row4_col0" class="data row4 col0" >0.273050</td>
#       <td id="T_71279_row4_col1" class="data row4 col1" >0.050887</td>
#       <td id="T_71279_row4_col2" class="data row4 col2" >-0.633990</td>
#       <td id="T_71279_row4_col3" class="data row4 col3" >0.004947</td>
#       <td id="T_71279_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_71279_row4_col5" class="data row4 col5" >0.231632</td>
#     </tr>
#     <tr>
#       <th id="T_71279_level0_row5" class="row_heading level0 row5" >Press_kPa</th>
#       <td id="T_71279_row5_col0" class="data row5 col0" >-0.236549</td>
#       <td id="T_71279_row5_col1" class="data row5 col1" >-0.320569</td>
#       <td id="T_71279_row5_col2" class="data row5 col2" >-0.231616</td>
#       <td id="T_71279_row5_col3" class="data row5 col3" >-0.356738</td>
#       <td id="T_71279_row5_col4" class="data row5 col4" >0.231632</td>
#       <td id="T_71279_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cr.shape[0]
# Out:
# 6

# %%
cr.index[1]
# Out:
# 'Dew Point Temp_C'

# %%
for i in range(1,cr.shape[0]):
  y=cr.index[i]
# Out:
# Dew Point Temp_C
# Rel Hum_%
# Wind Speed_km/h
# Visibility_km
# Press_kPa

# %%
y=cr.abs()
sorted(y[(y>0.2) & (y<1)]['Temp_C'])
# Out:
# [nan,
#  0.22013662886776492,
#  0.23654932461642045,
#  0.27305035358174456,
#  0.9326040620476937,
#  nan]

# %%
y.sort(key=DistanceFrom(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-aae888df7df4> in <cell line: 1>()
# ----> 1 y.sort(key=DistanceFrom(1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2105
# Mostly Cloudy                              2069
# Cloudy                                     1726
# Clear                                      1326
# Snow                                        389
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    115
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     36
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# Freezing Drizzle                              7
# Snow,Ice Pellets                              6
# Freezing Drizzle,Fog                          6
# Snow,Haze                                     5
# Freezing Fog                                  4
# Snow Showers,Fog                              4
# Moderate Snow                                 4
# Rain,Snow,Ice Pellets                         4
# Freezing Rain,Fog                             4
# Freezing Drizzle,Haze                         3
# Rain,Haze                                     3
# Thunderstorms,Rain                            3
# Thunderstorms,Rain Showers,Fog                3
# Freezing Rain,Haze                            2
# Drizzle,Snow                                  2
# Rain Showers,Snow Showers                     2
# Thunderstorms                                 2
# Moderate Snow,Blowing Snow                    2
# Rain Showers,Fog                              1
# Thunderstorms,Moderate Rain Showers,Fog       1
# Snow Pellets                                  1
# Rain,Snow,Fog                                 1
# Moderate Rain,Fog                             1
# Freezing Rain,Ice Pellets,Fog                 1
# Drizzle,Ice Pellets,Fog                       1
# Thunderstorms,Rain,Fog                        1
# Rain,Ice Pellets                              1
# Rain,Snow Grains                              1
# Thunderstorms,Heavy Rain Showers              1
# Freezing Rain,Snow Grains                     1
# Name: Weather, dtype: int64
