# %% [markdown]
# <a href="https://colab.research.google.com/github/qitinnstud/myfirstexperience/blob/For_homework/For_homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Импорт библиотеки pandas

# %%
import pandas as pd

# %% [markdown]
# Читаю DataFrame c GitHub в переменную df и вывожу несколько строк

# %%
#df.to_csv("drive/MyDrive/Weather_Data1.csv",sep='|',index=False)

url='https://raw.githubusercontent.com/qitinnstud/myfirstexperience/For_homework/Weather_Data.raw'
df = pd.read_csv(url, sep=',')
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 2  1/1/2012 2:00    -1.8              -3.4       89.0              7.0
# 3  1/1/2012 3:00    -1.5              -3.2       88.0              6.0
# 4  1/1/2012 4:00    -1.5              -3.3       88.0              7.0
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Замена типа 'object' на 'datestamp'

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %% [markdown]
# Подсчет пустых значений

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              5
# Dew Point Temp_C    8
# Rel Hum_%           2
# Wind Speed_km/h     2
# Visibility_km       4
# Press_kPa           5
# Weather             6
# dtype: int64

# %% [markdown]
# Всего пропусков:

# %%
df.isna().sum().sum()
# Out:
# 32

# %% [markdown]
# Сохраняем 'маску-пропуски' в DF x :

# %%
x=df.isnull()
x.head()
# Out:
#    Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      False   False             False      False            False
# 1      False   False             False      False            False
# 2      False   False             False      False            False
# 3      False   False             False      False            False
# 4      False   False             False      False            False
#
#    Visibility_km  Press_kPa  Weather
# 0          False      False    False
# 1          False      False    False
# 2          False      False    False
# 3          False      False    False
# 4          False      False    False

# %% [markdown]
# Выводим строки в котором есть хоть один NaN :

# %%
#df.loc[df.isnull()[:] == True] - не получилось...((
x['or']=x.astype('Int64').sum(axis=1).astype('bool') # Как требует ДЗ - применил функцию сложения! )
#Ну да, вопрос: как 'по-нормальному' векторизовать функцию OR в python?
df[x['or']!=False]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 48   2012-01-03 00:00:00    -9.0             -16.0       57.0
# 81   2012-01-04 09:00:00   -16.8               NaN       61.0
# 381  2012-01-16 21:00:00     NaN             -17.1       71.0
# 812  2012-02-03 20:00:00    -4.2               NaN       77.0
# 1447 2012-03-01 07:00:00    -4.9               NaN       83.0
# 1771 2012-03-14 19:00:00     0.3               NaN        NaN
# 2284 2012-04-05 04:00:00     NaN              -5.2       61.0
# 3246 2012-05-15 06:00:00    16.3               NaN       80.0
# 4116 2012-06-20 12:00:00    29.1               NaN       58.0
# 4497 2012-07-06 09:00:00     NaN              16.0       19.0
# 5623 2012-08-22 07:00:00    18.9              12.1       65.0
# 6455 2012-09-25 23:00:00     NaN               9.2       73.0
# 6877 2012-10-13 13:00:00     NaN              -2.8       45.0
# 7487 2012-11-07 23:00:00    -0.7              -4.7        NaN
# ...

# %% [markdown]
# То же:

# %%
# Нашел фукцию any ("Oh, how this all is not easy!"):
x['or']=x.any(axis=1)
df[x['or']==True]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 48   2012-01-03 00:00:00    -9.0             -16.0       57.0
# 81   2012-01-04 09:00:00   -16.8               NaN       61.0
# 381  2012-01-16 21:00:00     NaN             -17.1       71.0
# 812  2012-02-03 20:00:00    -4.2               NaN       77.0
# 1447 2012-03-01 07:00:00    -4.9               NaN       83.0
# 1771 2012-03-14 19:00:00     0.3               NaN        NaN
# 2284 2012-04-05 04:00:00     NaN              -5.2       61.0
# 3246 2012-05-15 06:00:00    16.3               NaN       80.0
# 4116 2012-06-20 12:00:00    29.1               NaN       58.0
# 4497 2012-07-06 09:00:00     NaN              16.0       19.0
# 5623 2012-08-22 07:00:00    18.9              12.1       65.0
# 6455 2012-09-25 23:00:00     NaN               9.2       73.0
# 6877 2012-10-13 13:00:00     NaN              -2.8       45.0
# 7487 2012-11-07 23:00:00    -0.7              -4.7        NaN
# ...

# %% [markdown]
# Выводим корреляционную "матрицу":

# %%
cr=df.corr()
cr.style.background_gradient(cmap='coolwarm')
# Out:
# <ipython-input-9-b3fc5f1be178>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cr=df.corr()
# <style type="text/css">
# #T_8af69_row0_col0, #T_8af69_row1_col1, #T_8af69_row2_col2, #T_8af69_row3_col3, #T_8af69_row4_col4, #T_8af69_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8af69_row0_col1, #T_8af69_row1_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_8af69_row0_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_8af69_row0_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_8af69_row0_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_8af69_row0_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8af69_row1_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# ...

# %% [markdown]
# Много хорошо скоррелированных величин. Создаем "Топ 5" значений корреляции:

# %%
y=[]
s=cr.shape[0]
for j in range(0,s-1):
    for i in range(j+1,s):
        yy=cr.loc[cr.index[i]][cr.columns[j]]
        y+=[[cr.index[i], '<--->',cr.columns[j], yy, abs(yy)]]
y=pd.DataFrame(y)
y=y.sort_values(4, ascending=False)
y.head()
# Out:
#                    0      1                 2         3         4
# 0   Dew Point Temp_C  <--->            Temp_C  0.932604  0.932604
# 10     Visibility_km  <--->         Rel Hum_% -0.633990  0.633990
# 13         Press_kPa  <--->   Wind Speed_km/h -0.356738  0.356738
# 8          Press_kPa  <--->  Dew Point Temp_C -0.320569  0.320569
# 3      Visibility_km  <--->            Temp_C  0.273050  0.273050

# %% [markdown]
# Наблюдаем корреляции: прямые и обратные, от заметных и значительных до больших.
#
# **Вывод:**
#
# **"Физика рулит"!**

# %% [markdown]
# Получаем уникальные значения в столбце 'Погода'

# %%
print(*df['Weather'].unique(), sep='\n')
# Out:
# Fog
# Freezing Drizzle,Fog
# Mostly Cloudy
# Cloudy
# Rain
# Rain Showers
# Mainly Clear
# Snow Showers
# Snow
# Clear
# Freezing Rain,Fog
# Freezing Rain
# Freezing Drizzle
# Rain,Snow
# Moderate Snow
# Freezing Drizzle,Snow
# Freezing Rain,Snow Grains
# Snow,Blowing Snow
# Freezing Fog
# Haze
# Rain,Fog
# Drizzle,Fog
# Drizzle
# Freezing Drizzle,Haze
# Freezing Rain,Haze
# Snow,Haze
# Snow,Fog
# Snow,Ice Pellets
# Rain,Haze
# nan
# Thunderstorms,Rain
# Thunderstorms,Rain Showers
# Thunderstorms,Heavy Rain Showers
# Thunderstorms,Rain Showers,Fog
# Thunderstorms
# Thunderstorms,Rain,Fog
# Thunderstorms,Moderate Rain Showers,Fog
# Rain Showers,Fog
# Rain Showers,Snow Showers
# Snow Pellets
# Rain,Snow,Fog
# Moderate Rain,Fog
# Freezing Rain,Ice Pellets,Fog
# Drizzle,Ice Pellets,Fog
# Drizzle,Snow
# Rain,Ice Pellets
# Drizzle,Snow,Fog
# Rain,Snow Grains
# Rain,Snow,Ice Pellets
# Snow Showers,Fog
# Moderate Snow,Blowing Snow

# %% [markdown]
# (nan "затесался" среди прочего)

# %% [markdown]
# Частота "качественных характеристик" погоды (визуально):

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2105
# Mostly Cloudy                              2069
# Cloudy                                     1726
# Clear                                      1326
# Snow                                        389
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    115
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     36
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# Случайная выборка из 20 значений:

# %%
dfs=df.sample(20); dfs
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 343  2012-01-15 07:00:00   -22.8             -28.0       62.0
# 1339 2012-02-25 19:00:00    -4.7             -10.5       64.0
# 4727 2012-07-15 23:00:00    21.8              19.1       85.0
# 2519 2012-04-14 23:00:00    11.6               0.3       46.0
# 5590 2012-08-20 22:00:00    18.5              10.0       58.0
# 8187 2012-12-07 03:00:00    -1.8              -5.3       77.0
# 5931 2012-09-04 03:00:00    20.9              15.3       70.0
# 6067 2012-09-09 19:00:00    15.2               8.6       65.0
# 5746 2012-08-27 10:00:00    26.0              17.9       61.0
# 7396 2012-11-04 04:00:00     2.9              -0.9       76.0
# 6486 2012-09-27 06:00:00     6.4               4.3       86.0
# 4247 2012-06-25 23:00:00    16.7              11.6       72.0
# 19   2012-01-01 19:00:00     3.1               1.3       88.0
# 4626 2012-07-11 18:00:00    27.3               8.0       30.0
# ...

# %%
def frame(x, y):
    x=x[y]
    x=[x.min(), x.median(), round(x.mean(),3), x.max(), round(x.std(),3)]
    y=['min:', 'median:','mean:', 'max:', 'std:','value']
    dfx=pd.DataFrame(x, index=y[:5], columns=[y[5]])
    return dfx

# %%
dfxt1=frame(dfs,'Temp_C')
dfxt1
# Out:
#           value
# min:    -22.800
# median:   5.200
# mean:     6.840
# max:     27.300
# std:     13.687

# %%
dfxt2=frame(dfs,'Dew Point Temp_C')
dfxt2
# Out:
#           value
# min:    -28.000
# median:   2.500
# mean:     1.650
# max:     19.100
# std:     11.968

# %% [markdown]
# Применим операторы сравненеия.

# %% [markdown]
# Сравнение аггригированных значений температур:

# %%
print(dfxt1 <= dfxt2)
# Out:
#          value
# min:     False
# median:  False
# mean:    False
# max:     False
# std:     False

# %% [markdown]
# Выбор некоторых значений из корреляционной матрицы:

# %%
newcr=cr[(abs(cr)<1)&(abs(cr)>0.2)]
newcr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_87f96_row0_col0, #T_87f96_row1_col1, #T_87f96_row1_col2, #T_87f96_row1_col4, #T_87f96_row2_col1, #T_87f96_row2_col2, #T_87f96_row3_col0, #T_87f96_row3_col1, #T_87f96_row3_col2, #T_87f96_row3_col4, #T_87f96_row4_col1, #T_87f96_row4_col4, #T_87f96_row5_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_87f96_row0_col1, #T_87f96_row0_col2, #T_87f96_row0_col4, #T_87f96_row1_col0, #T_87f96_row4_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_87f96_row0_col3, #T_87f96_row1_col3, #T_87f96_row2_col3, #T_87f96_row2_col4, #T_87f96_row3_col3, #T_87f96_row3_col5, #T_87f96_row4_col2, #T_87f96_row4_col3, #T_87f96_row5_col0, #T_87f96_row5_col1, #T_87f96_row5_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_87f96_row0_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_87f96_row1_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_87f96_row2_col0 {
#   background-color: #3e51c5;
# ...
